# %% [markdown]
# # EAD Calculation
#
# Apply funded and revolving-facility logic to calculate Exposure at Default.

# %%
from pathlib import Path
import sys
import pandas as pd

ROOT = Path.cwd().resolve()
if not (ROOT / "data").exists():
    ROOT = ROOT.parent
sys.path.insert(0, str(ROOT))

from src.data_loader import load_input_tables
from src.expected_loss import build_expected_loss_dataset

inputs = load_input_tables()
loan_level_df = build_expected_loss_dataset(inputs["portfolio"], inputs["pd_final"], inputs["lgd_final"])
loan_level_df[["facility_id", "product_type", "drawn_balance", "undrawn_amount", "ccf_bucket", "ccf_applied", "ead"]].head()
