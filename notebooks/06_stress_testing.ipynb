# %% [markdown]
# # Stress Testing
#
# Apply the base, mild, and severe scenario overlays and compare stressed expected loss versus the base case.

# %%
from pathlib import Path
import sys
import pandas as pd

ROOT = Path.cwd().resolve()
if not (ROOT / "data").exists():
    ROOT = ROOT.parent
sys.path.insert(0, str(ROOT))

from src.pipeline import run_pipeline

run_pipeline(persist=True)
stress_results = pd.read_csv(ROOT / "data" / "output" / "stress_test_results.csv")
stress_results
