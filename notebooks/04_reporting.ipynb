# %% [markdown]
# # Expected-Loss-Engine-Australia - Reporting
#
# Standard notebook placeholder for the rebuilt Expected-Loss-Engine-Australia workflow.

# %%
from src.codex_run_pipeline import run_pipeline
result = run_pipeline(persist=True)
result["validation"].head()
