# %% [markdown]
# # expected-loss-engine-commercial - Reporting
#
# Standard notebook placeholder for the rebuilt expected-loss-engine-commercial workflow.

# %%
from src.pipeline import run_pipeline
result = run_pipeline(persist=True)
result["validation"].head()
