# %% [markdown]
# # Pricing Analysis
#
# Translate expected loss into a pricing hurdle and compare booked margin against the required margin.

# %%
from pathlib import Path
import sys
import pandas as pd

ROOT = Path.cwd().resolve()
if not (ROOT / "data").exists():
    ROOT = ROOT.parent
sys.path.insert(0, str(ROOT))

from src.pipeline import run_pipeline

result = run_pipeline(persist=True)
pricing_table = pd.read_csv(ROOT / "data" / "output" / "pricing_table.csv")
pricing_table
